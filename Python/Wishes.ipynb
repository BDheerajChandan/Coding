# %%
from colorama import init, Fore
import time
init()
print(time.ctime())
print(Fore.BLUE+"Wishing You a 🎉Happy Birthday💖🎂 Dear Chelli💕, \n Wishes from your bro Dheeraj")
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
file_path=input()
# Load the image
img1=plt.imread(f"{file_path}")
plt.figure(figsize=[10,15])
plt.subplot(1, 2, 1)
plt.imshow(img1)
plt.axis('off')
#
#"C:\Users\KIIT\Downloads\Dheeraj@TechnologyHunter.png"
img2=plt.imread(f"{file_path}")
plt.subplot(1, 2, 2)
plt.imshow(img2)
plt.axis('off')

# Add the birthday message on the image
plt.text(0, 0, "Dheeraj YouTube Channel\nChannelName :Dheeraj@TechnologyHunter",
         color='green', fontsize=15, ha='left', va='bottom', fontweight='bold')

# Show the image
plt.show()
# Out:
# Wed Nov 27 00:14:28 2024
# Wishing You a 🎉Happy Birthday💖🎂 Dear Chelli💕,
#  Wishes from your bro Dheeraj
