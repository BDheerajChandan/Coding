# %% [markdown]
# # File and folder

# %%
import os
os.listdir()
# Out:
# ['.gitkeep',
#  '10_Hyoerparameters.ipynb',
#  '1_2_3_4 Regression - Linear Regression and SaveModel.ipynb',
#  '5_LogisticRegression&ConfusionMatrix.ipynb',
#  '6_Pandas&EDA.ipynb',
#  '7_SVM.ipynb',
#  '8_KNN&NaiveBayes.ipynb',
#  '9_DecisionTree.ipynb',
#  'Classification - LogisticRegression&ConfusionMatrix.ipynb',
#  'Classification(LR+SVM+DT+RF)_1.ipynb',
#  'DecisionTree_Randomforest.ipynb',
#  'Employee_attrition_Logistic.csv',
#  'framingham_Logistic.csv',
#  'heart_logistic.csv',
#  'Housing+Case+Study+using+RFE.ipynb',
#  'Lasso_MLR.ipynb',
#  'Lasso_SLR.ipynb',
#  'Logistic+Regression+-+Telecom+Churn+Case+Study.ipynb',
#  'Metrics.ipynb',
#  'MLR_1.ipynb',
#  'movie_review_test.csv',
#  'movie_review_train.csv',
#  'Multiple+Linear+Regression+-+Housing+Case+Study (1).ipynb',
#  'Multiple+Linear+Regression+-+Housing+Case+Study.ipynb',
#  'Pearson_SimpleLinear.txt',
#  'Ridge_MLR.ipynb',
#  'Ridge_SLR.ipynb',
#  'SLR_1.ipynb',
#  'student-por.csv',
#  'test_DecisionTree.csv',
#  'train_DecisionTree.csv',
#  'winequality-red_multilinear.csv',
#  'winequality-white_multilinear.csv']

# %% [markdown]
# # Load data

# %%
import pandas as pd
data=pd.read_csv("Pearson_SimpleLinear.txt",sep="\t")
data.head()
# Out:
#    Father   Son
# 0    65.0  59.8
# 1    63.3  63.2
# 2    65.0  63.3
# 3    65.8  62.8
# 4    61.1  64.3

# %% [markdown]
# # Plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.pairplot(data)
plt.show()

# %%
sns.heatmap(data.corr(),annot=True)
plt.show()

# %% [markdown]
# # Split data

# %%
from sklearn.model_selection import train_test_split
x=data["Father"]
y=data["Son"]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)
print("Length of x_train : ",len(x_train))
print("Length of y_train : ",len(y_train))
print("Length of x_test : ",len(x_test))
print("Length of y_test : ",len(y_test))
# Out:
# Length of x_train :  754
# Length of y_train :  754
# Length of x_test :  324
# Length of y_test :  324

# %% [markdown]
# # Train data

# %%
from sklearn.linear_model import Lasso #LinearRegression
import numpy as  np
#model=LinearRegression()
model=Lasso(alpha=0.5)
model.fit(np.array(x_train).reshape(-1,1),np.array(y_train).reshape(-1,1))
# Out:
#  68.53632128 70.02295283 68.2209752  71.05908998 70.87889221 67.00464029
#  69.48235954 69.16701346 66.50909644 65.38286041 70.69869445 68.67146961
#  68.67146961 67.72543135 69.30216178 68.08582687 68.62642016 68.17592575
#  69.48235954 67.99572799 65.20266265 68.13087631 68.35612352 69.93285395
#  70.29324948 69.79770563 67.36503582 67.95067855 70.06800228 69.52740898
#  69.12196402 68.2209752  69.03186513 67.59028302 67.04968973 69.03186513
#  70.74374389 66.01355259 67.31998638 67.13978861 68.89671681 66.6892942
#  66.82444253 70.11305172 67.99572799 70.2031506  69.34721122 66.91454141
#  70.24820004 69.34721122 68.89671681 67.04968973 68.71651905 69.07691457
#  68.98681569 70.33829892 69.25711234 67.72543135 70.38334836 69.4373101
#  67.77048079 67.63533246 70.33829892 67.50018414 66.23879979 69.70760675
#  68.67146961 68.31107408 67.27493694 67.86057967 70.02295283 70.74374389
#  68.71651905 67.36503582 70.87889221 68.4462224  69.25711234 66.95959085
#  67.86057967 67.95067855 67.41008526 70.38334836 67.4551347  67.27493694
#  67.6803819  70.65364501 69.48235954 69.16701346 68.67146961 68.2209752
#  69.34721122 68.80661793 68.71651905 68.4462224  68.80661793 67.90562911
#  69.97790339 69.57245842 66.64424476 68.2209752  68.49127184 70.69869445
#  67.36503582 69.75265619 67.90562911 68.40117296 67.86057967 68.85166737]

# %%
plt.scatter(x_test,y_test,color='blue', label='Actual values')
plt.plot(x_test,y_pred,color='red', label='Predicted values')
plt.xlabel('Independent Variable [ x ]')
plt.ylabel('Dependent Variable [ y ]')
plt.title('Actual vs Predicted Values')
plt.legend()
plt.show()

# %% [markdown]
# # Evaluation Metrics

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
model_mae=mean_absolute_error(y_test,y_pred)
model_mse=mean_squared_error(y_test,y_pred)
model_rmse=np.sqrt(mean_squared_error(y_test,y_pred))
model_r2s=r2_score(y_test,y_pred)
train_score=model.score(np.array(x_train).reshape(-1,1),np.array(y_train).reshape(-1,1))
test_score=model.score(np.array(x_test).reshape(-1,1),np.array(y_test).reshape(-1,1))
model_intercept=model.intercept_
model_coeff=model.coef_

print("Model intercept : ",model.intercept_)
print("Model coefficient : ",model.coef_)
print("Train score : ",train_score)
print("Test score : ",test_score)
print("R2 score error : ",model_r2s)
print("Mean absolute error : ",model_mae)
print("Mean squared error : ",model_mse)
print("Root Mean square error : ",model_rmse)
# Out:
# Model intercept :  [38.17299807]
# Model coefficient :  [0.45049441]
# Train score :  0.26357694820706323
# Test score :  0.21460291817879396
# R2 score error :  0.21460291817879396
# Mean absolute error :  2.0336761662719183
# Mean squared error :  7.087272181262065
# Root Mean square error :  2.6621931149452824
