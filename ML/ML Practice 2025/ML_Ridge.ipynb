# %% [markdown]
# # 1. Read or Extract data

# %%
import os
os.listdir("Dataset_Files")
# Out:
# ['.gitkeep',
#  '50_Startups.csv',
#  'Churn_Modelling.csv',
#  'Employee_attrition.csv',
#  'Housing.csv',
#  'Income&Expenditure.xlsx',
#  'Mall_Customers.csv',
#  'movie_review_test.csv',
#  'movie_review_train.csv',
#  'Passenger_test.csv',
#  'Passenger_train.csv',
#  'Pearson.txt',
#  'Position_Salaries.csv',
#  'Result_Datasets',
#  'Salary_Data.csv',
#  'Social_Network_Ads.csv',
#  'Stud_part1.csv',
#  'Stud_part2.csv',
#  'winequality-red.csv',
#  'winequality-white.csv']

# %%
import pandas as pd
data=pd.read_csv("Dataset_Files\\Housing.csv")
data
# Out:
#        Unnamed: 0  MedInc  HouseAge  AveRooms  AveBedrms  Population  \
# 0               0  8.3252      41.0  6.984127   1.023810       322.0
# 1               1  8.3014      21.0  6.238137   0.971880      2401.0
# 2               2  7.2574      52.0  8.288136   1.073446       496.0
# 3               3  5.6431      52.0  5.817352   1.073059       558.0
# 4               4  3.8462      52.0  6.281853   1.081081       565.0
# ...           ...     ...       ...       ...        ...         ...
# 20635       20635  1.5603      25.0  5.045455   1.133333       845.0
# 20636       20636  2.5568      18.0  6.114035   1.315789       356.0
# 20637       20637  1.7000      17.0  5.205543   1.120092      1007.0
# 20638       20638  1.8672      18.0  5.329513   1.171920       741.0
# 20639       20639  2.3886      16.0  5.254717   1.162264      1387.0
#
#        AveOccup  Latitude  Longitude  target
# 0      2.555556     37.88    -122.23   4.526
# 1      2.109842     37.86    -122.22   3.585
# ...

# %% [markdown]
# # 2. EDA

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  20640 non-null  int64
#  1   MedInc      20640 non-null  float64
#  2   HouseAge    20640 non-null  float64
#  3   AveRooms    20640 non-null  float64
#  4   AveBedrms   20640 non-null  float64
#  5   Population  20640 non-null  float64
#  6   AveOccup    20640 non-null  float64
#  7   Latitude    20640 non-null  float64
#  8   Longitude   20640 non-null  float64
#  9   target      20640 non-null  float64
# dtypes: float64(9), int64(1)
# memory usage: 1.6 MB

# %% [markdown]
# # 3.Feature Extraction

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
def f(i):
    data[i]=le.fit_transform(data[i])
for i in list(data.columns[data.dtypes=="object"]):
    f(i)

data
# Out:
#        Unnamed: 0  MedInc  HouseAge  AveRooms  AveBedrms  Population  \
# 0               0  8.3252      41.0  6.984127   1.023810       322.0
# 1               1  8.3014      21.0  6.238137   0.971880      2401.0
# 2               2  7.2574      52.0  8.288136   1.073446       496.0
# 3               3  5.6431      52.0  5.817352   1.073059       558.0
# 4               4  3.8462      52.0  6.281853   1.081081       565.0
# ...           ...     ...       ...       ...        ...         ...
# 20635       20635  1.5603      25.0  5.045455   1.133333       845.0
# 20636       20636  2.5568      18.0  6.114035   1.315789       356.0
# 20637       20637  1.7000      17.0  5.205543   1.120092      1007.0
# 20638       20638  1.8672      18.0  5.329513   1.171920       741.0
# 20639       20639  2.3886      16.0  5.254717   1.162264      1387.0
#
#        AveOccup  Latitude  Longitude  target
# 0      2.555556     37.88    -122.23   4.526
# 1      2.109842     37.86    -122.22   3.585
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  20640 non-null  int64
#  1   MedInc      20640 non-null  float64
#  2   HouseAge    20640 non-null  float64
#  3   AveRooms    20640 non-null  float64
#  4   AveBedrms   20640 non-null  float64
#  5   Population  20640 non-null  float64
#  6   AveOccup    20640 non-null  float64
#  7   Latitude    20640 non-null  float64
#  8   Longitude   20640 non-null  float64
#  9   target      20640 non-null  float64
# dtypes: float64(9), int64(1)
# memory usage: 1.6 MB

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=[15,5])
sns.boxplot(data)
plt.xticks(rotation=60)
plt.show()

# %%
import seaborn as sns
sns.pairplot(data)
plt.show()

# %%
plt.figure(figsize=[10,10])
sns.heatmap(data.corr(),annot=True)
# Out:
# <Axes: >

# %%
def f(i):
    q1=data[i].quantile(0.25)
    q3=data[i].quantile(0.75)
    IQR=q3-q1

    lb=q1-(IQR*1.5)
    ub=q3+(IQR*1.5)

    data.loc[data[i]<lb,i]=lb
    data.loc[data[i]>ub,i]=ub

for i in data.columns:
    f(i)

plt.figure(figsize=[15,5])
sns.boxplot(data)
plt.xticks(rotation=60)
plt.show()

# %%
x=data.iloc[:,1:-1]
y=data.iloc[:,-1]
x
# Out:
#          MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# 0      8.013025      41.0  6.984127   1.023810       322.0  2.555556
# 1      8.013025      21.0  6.238137   0.971880      2401.0  2.109842
# 2      7.257400      52.0  8.288136   1.073446       496.0  2.802260
# 3      5.643100      52.0  5.817352   1.073059       558.0  2.547945
# 4      3.846200      52.0  6.281853   1.081081       565.0  2.181467
# ...         ...       ...       ...        ...         ...       ...
# 20635  1.560300      25.0  5.045455   1.133333       845.0  2.560606
# 20636  2.556800      18.0  6.114035   1.239697       356.0  3.122807
# 20637  1.700000      17.0  5.205543   1.120092      1007.0  2.325635
# 20638  1.867200      18.0  5.329513   1.171920       741.0  2.123209
# 20639  2.388600      16.0  5.254717   1.162264      1387.0  2.616981
#
#        Latitude  Longitude
# 0         37.88    -122.23
# 1         37.86    -122.22
# 2         37.85    -122.24
# ...

# %%
y
# Out:
# 0        4.526
# 1        3.585
# 2        3.521
# 3        3.413
# 4        3.422
#          ...
# 20635    0.781
# 20636    0.771
# 20637    0.923
# 20638    0.847
# 20639    0.894
# Name: target, Length: 20640, dtype: float64

# %% [markdown]
# # 4. Model Building

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
from sklearn.linear_model import Ridge
model_ridge=Ridge(alpha=0.1)
model_ridge.fit(x_train,y_train)
# Out:
# Ridge(alpha=0.1)

# %%
import joblib
joblib.dump(model_ridge,"New_model_ridge.pickle")
Load_model_ridge=joblib.load("New_model_ridge.pickle")

# %% [markdown]
# # 5. Model Prediction

# %%
y_pred=Load_model_ridge.predict(x_test)
y_pred
# Out:
# array([0.25657492, 1.96602446, 3.41759365, ..., 4.043568  , 1.24595045,
#        1.67679385])

# %% [markdown]
# # 6. Model Evaluation

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error
import numpy as np
print(mean_absolute_error(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
print(np.sqrt(mean_squared_error(y_test,y_pred)))

print(Load_model_ridge.score(x_test,y_test))
print(Load_model_ridge.score(x_train,y_train))
# Out:
# 0.49466651000152745
# 0.44240904310926443
# 0.6651383638832332
# 0.6500914363072943
# 0.6745169224829723

# %% [markdown]
# # 7. Result Visyualization

# %%
import matplotlib.pyplot as plt
plt.plot(x_test[len(x_test)-len(y_test):,0],y_test)
plt.plot(x_test[len(x_test)-len(y_test):,0],y_pred)
plt.show()

# %%
import seaborn as sns
sns.distplot(y_test)
sns.distplot(y_pred)
plt.show()
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_12696\1327518496.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_test)
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_12696\1327518496.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_pred)
