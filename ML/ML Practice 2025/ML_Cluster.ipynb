# %% [markdown]
# # 1. Read or Extract data

# %%
import os
os.listdir(path="Dataset_Files")
# Out:
# ['.gitkeep',
#  '50_Startups.csv',
#  'Churn_Modelling.csv',
#  'Employee_attrition.csv',
#  'Housing.csv',
#  'Mall_Customers.csv',
#  'movie_review_test.csv',
#  'movie_review_train.csv',
#  'Passenger_test.csv',
#  'Passenger_train.csv',
#  'Pearson.txt',
#  'Position_Salaries.csv',
#  'Result_Datasets',
#  'Salary_Data.csv',
#  'Social_Network_Ads.csv',
#  'Stud_part1.csv',
#  'Stud_part2.csv',
#  'winequality-red.csv',
#  'winequality-white.csv']

# %%
import pandas as pd
data=pd.read_csv("Dataset_Files\\Pearson.txt",sep="\t")
data
# Out:
#       Father   Son
# 0       65.0  59.8
# 1       63.3  63.2
# 2       65.0  63.3
# 3       65.8  62.8
# 4       61.1  64.3
# ...      ...   ...
# 1073    67.0  70.8
# 1074    71.3  68.3
# 1075    71.8  69.3
# 1076    70.7  69.3
# 1077    70.3  67.0
#
# [1078 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
plt.scatter(data.iloc[:,0],data.iloc[:,1])

# %% [markdown]
# # 2. EDA

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1078 entries, 0 to 1077
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Father  1078 non-null   float64
#  1   Son     1078 non-null   float64
# dtypes: float64(2)
# memory usage: 17.0 KB

# %%
data.describe()
# Out:
#             Father          Son
# count  1078.000000  1078.000000
# mean     67.686827    68.684230
# std       2.745827     2.816194
# min      59.000000    58.500000
# 25%      65.800000    66.900000
# 50%      67.800000    68.600000
# 75%      69.600000    70.500000
# max      75.400000    78.400000

# %%
data.isnull().sum()
# Out:
# Father    0
# Son       0
# dtype: int64

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=4)
kmeans.fit(data)
centers = kmeans.cluster_centers_
labels = kmeans.labels_

# Plotting the data points and centroids
plt.scatter(data.iloc[:, 0], data.iloc[:, 1], c=labels, cmap='viridis', marker='o', edgecolor='black', s=50)
plt.scatter(centers[:, 0], centers[:, 1], c='red', s=200, marker='X')
plt.show()
# Out:
# c:\Users\KIIT\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
from sklearn.cluster import KMeans
kmeans=KMeans(n_clusters=5)
kmeans.fit(data)
# Out:
# c:\Users\KIIT\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# KMeans(n_clusters=5)

# %%
cen=kmeans.cluster_centers_
lbl=kmeans.labels_

# %%
import matplotlib.pyplot as plt
plt.scatter(data.iloc[:,0],data.iloc[:,1],cmap='viridis',c=lbl,edgecolors="black",s=50)
plt.scatter(cen[:,0],cen[:,1],c="red",s=200,marker="X")
#plt.scatter(centers[:, 0], centers[:, 1], c='red', s=200, marker='X')

# %%
plt.scatter(data.iloc[:, 0], data.iloc[:, 1], c=labels, cmap='viridis', marker='o', edgecolor='black', s=50)
plt.scatter(cen[:, 0], cen[:, 1], c='red', s=200, marker='X')
